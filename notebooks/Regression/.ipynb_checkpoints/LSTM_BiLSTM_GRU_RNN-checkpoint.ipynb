# %%
from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout, LSTM, Bidirectional, GRU, SimpleRNN
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
from sklearn import preprocessing
import numpy as np
import pandas as pd
from ta import add_all_ta_features # Library that does financial technical analysis 

from sklearn.preprocessing import MinMaxScaler 
scaler = MinMaxScaler(feature_range=(0, 1))

import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
hist = pd.read_csv('Data/WAFA-ASSURANCE.csv', index_col="Date", parse_dates=True)

# Add all technical analysis to the dataframe we've already loaded
hist = add_all_ta_features(hist, "Open", "High", "Low", "Close", "Volume", fillna=True) 

target_col = 'Close'

window_len = 5
test_size = 0.2
zero_base = True
print(hist)
# Out:
# C:\Users\bentaleb.khalid\Anaconda3\lib\site-packages\ta\trend.py:768: RuntimeWarning: invalid value encountered in double_scalars
#   dip[i] = 100 * (self._dip[i] / self._trs[i])
# C:\Users\bentaleb.khalid\Anaconda3\lib\site-packages\ta\trend.py:772: RuntimeWarning: invalid value encountered in double_scalars
#   din[i] = 100 * (self._din[i] / self._trs[i])
#                Open     High      Low    Close   Volume     volume_adi  \
# Date
# 2000-01-03   594.36   603.11   603.11   603.11   840.90       0.000000
# 2000-01-04   607.98   611.87   611.87   611.87  1761.99       0.000000
# 2000-01-05   617.70   617.70   617.70   617.70   177.84       0.000000
# 2000-01-06   620.62   617.70   617.70   617.70   642.50       0.000000
# 2000-01-07   614.79   617.70   617.70   617.70   204.57       0.000000
# ...             ...      ...      ...      ...      ...            ...
# 2021-11-05  4880.00  4880.00  4870.00  4870.00   117.00  805861.634965
# 2021-11-10  4850.00  4850.00  4850.00  4850.00   379.00  805861.634965
# 2021-11-12  4700.00  4700.00  4700.00  4700.00    16.00  805861.634965
# 2021-11-16  4800.00  4800.00  4800.00  4800.00     6.00  805861.634965
# 2021-11-17  4660.00  4800.00  4660.00  4800.00     9.00  805870.634965
#
#             volume_obv  volume_cmf     volume_fi  volume_mfi  ...  \
# Date                                                          ...
# 2000-01-03      840.90    0.000000      0.000000   50.000000  ...
# 2000-01-04     2602.89    0.000000  15435.032400  100.000000  ...
# 2000-01-05     2780.73    0.000000  13378.143086  100.000000  ...
# 2000-01-06     3423.23    0.000000  11466.979788  100.000000  ...
# 2000-01-07     3627.80    0.000000   9828.839818  100.000000  ...
# ...                ...         ...           ...         ...  ...
# 2021-11-05  2002465.72    0.255388  26429.208111   91.447537  ...
# 2021-11-10  2002086.72    0.262788  21570.749810   87.341411  ...
# 2021-11-12  2002070.72    0.473595  18146.356980   95.001565  ...
# 2021-11-16  2002076.72    0.569556  15639.734554   94.999501  ...
# 2021-11-17  2002085.72    0.570760  13405.486761   93.144154  ...
#
#             momentum_wr  momentum_ao  momentum_kama  momentum_roc  \
# Date
# 2000-01-03   -50.000000     0.000000     603.110000      0.000000
# 2000-01-04    -0.000000     0.000000     606.974090      0.000000
# 2000-01-05    -0.000000     0.000000     611.783828      0.000000
# 2000-01-06    -0.000000     0.000000     614.493718      0.000000
# 2000-01-07    -0.000000     0.000000     615.961729      0.000000
# ...                 ...          ...            ...           ...
# 2021-11-05    -6.666667   411.576471    4855.401654      9.438202
# 2021-11-10   -11.111111   404.723529    4853.962712      8.744395
# 2021-11-12   -44.444444   367.605882    4848.696400      4.444444
# 2021-11-16   -22.222222   346.164706    4845.270680      5.494505
# 2021-11-17   -28.571429   308.882353    4842.085954      4.347826
#
#             momentum_ppo  momentum_ppo_signal  momentum_ppo_hist  others_dr  \
# Date
# 2000-01-03      0.000000             0.000000           0.000000 -71.099446
# 2000-01-04      8.082161             1.616432           6.465729   1.452471
# 2000-01-05      0.448751             1.382896          -0.934145   0.952817
# 2000-01-06     -1.632696             0.779777          -2.412474   0.000000
# 2000-01-07     -7.854155            -0.947009          -6.907146   0.000000
# ...                  ...                  ...                ...        ...
# 2021-11-05    -24.182671           -17.794580          -6.388091  -0.591958
# 2021-11-10    -26.116741           -19.459012          -6.657730  -0.410678
# 2021-11-12    -32.270078           -22.021225         -10.248853  -3.092784
# 2021-11-16    -38.016026           -25.220185         -12.795840   2.127660
# 2021-11-17    -43.206547           -28.817458         -14.389089   0.000000
#
#             others_dlr   others_cr
# Date
# 2000-01-03    0.000000    0.000000
# 2000-01-04    1.442024    1.452471
# 2000-01-05    0.948306    2.419128
# 2000-01-06    0.000000    2.419128
# 2000-01-07    0.000000    2.419128
# ...                ...         ...
# 2021-11-05   -0.593717  707.481222
# 2021-11-10   -0.411523  704.165078
# 2021-11-12   -3.141620  679.293993
# 2021-11-16    2.105341  695.874716
# 2021-11-17    0.000000  695.874716
#
# [4011 rows x 88 columns]

# %%
def train_test_split(df, test_size=0.2):
    split_row = len(df) - int(test_size * len(df))
    train_data = df.iloc[:split_row]
    test_data = df.iloc[split_row:]
    return train_data, test_data

train, test = train_test_split(hist, test_size=0.2)

# %%
def line_plot(line1, line2, label1=None, label2=None, title='Close Price history', lw=2):
    fig, ax = plt.subplots(1, figsize=(16, 8))
    ax.plot(line1, label=label1, linewidth=lw)
    ax.plot(line2, label=label2, linewidth=lw)
    ax.set_ylabel('Price', fontsize=14)
    ax.set_title(title, fontsize=16)
    ax.legend(loc='best', fontsize=16)
    plt.show()

line_plot(train[target_col], test[target_col], 'training', 'test', title='Close Price history')

# %%
def extract_window_data(df, window_len=5, zero_base=True):
    window_data = []
    for idx in range(len(df) - window_len):
        tmp = df[idx: (idx + window_len)].copy()
        if zero_base:
            X = tmp.values
            # X = preprocessing.scale(X)
            X = scaler.fit_transform(X)
        window_data.append(X)
    return np.array(window_data)

# %%
def prepare_data(df, target_col, window_len=5, zero_base=True, test_size=0.2):
    train_data, test_data = train_test_split(df, test_size=test_size)
    X_train = extract_window_data(train_data, window_len, zero_base)
    X_test = extract_window_data(test_data, window_len, zero_base)
    y_train = train_data[target_col][window_len:].values
    y_test = test_data[target_col][window_len:].values
    if zero_base:
        y_train = y_train / train_data[target_col][:-window_len].values - 1
        y_test = y_test / test_data[target_col][:-window_len].values - 1
    return train_data, test_data, X_train, X_test, y_train, y_test

# %%
train, test, X_train, X_test, y_train, y_test = prepare_data(
    hist, target_col, window_len=window_len, zero_base=zero_base, test_size=test_size)

targets = test[target_col][window_len:]

# %%
def build_lstm_model(X_train, y_train, X_test, y_test):
    # The LSTM architecture
    regressorLSTM = Sequential()    
    regressorLSTM.add(LSTM(256, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))
    regressorLSTM.add(Dropout(0.2))
    regressorLSTM.add(LSTM(128, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))
    regressorLSTM.add(Dropout(0.2))
    regressorLSTM.add(LSTM(64, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
    regressorLSTM.add(Dropout(0.2))
    regressorLSTM.add(Dense(32,kernel_initializer="uniform",activation='relu'))        
    regressorLSTM.add(Dense(1,kernel_initializer="uniform",activation='linear'))
    regressorLSTM.add(Activation("linear"))

    regressorLSTM.compile(loss="mean_squared_error", optimizer="adam", metrics=['accuracy'])
    regressorLSTM.fit(X_train, y_train, epochs=100, batch_size=96)
    lstm_pred = regressorLSTM.predict(X_test).squeeze()

    lstm_MSE = mean_squared_error(y_test, lstm_pred)
    lstm_MAE = mean_absolute_error(y_test, lstm_pred)
    lstm_RMSE = np.sqrt(np.mean(np.power((np.array(y_test)-np.array(lstm_pred)),2)))
    print('LSTM Mean Absolute Error: {}'.format(lstm_MAE))
    print('LSTM MSE: {}'.format(lstm_MSE))
    print('LSTM RMSE: {}'.format(lstm_RMSE))

    return regressorLSTM, lstm_pred, lstm_MSE, lstm_MAE, lstm_RMSE

# %%
regressorLSTM, lstm_pred, lstm_MSE, lstm_MAE, lstm_RMSE = build_lstm_model(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/100
# 34/34 [==============================] - 11s 54ms/step - loss: 0.0016 - accuracy: 0.0462
# Epoch 2/100
# 34/34 [==============================] - 2s 45ms/step - loss: 0.0012 - accuracy: 0.0462
# Epoch 3/100
# 34/34 [==============================] - 1s 42ms/step - loss: 0.0011 - accuracy: 0.0462
# Epoch 4/100
# 34/34 [==============================] - 2s 54ms/step - loss: 0.0010 - accuracy: 0.0462
# Epoch 5/100
# 34/34 [==============================] - 2s 49ms/step - loss: 9.7498e-04 - accuracy: 0.0462
# Epoch 6/100
# 34/34 [==============================] - 2s 49ms/step - loss: 0.0010 - accuracy: 0.0462
# Epoch 7/100
# 34/34 [==============================] - 2s 48ms/step - loss: 9.3095e-04 - accuracy: 0.0462
# Epoch 8/100
# 34/34 [==============================] - 1s 39ms/step - loss: 9.0646e-04 - accuracy: 0.0462
# Epoch 9/100
# 34/34 [==============================] - 2s 44ms/step - loss: 9.0373e-04 - accuracy: 0.0462
# Epoch 10/100
# 34/34 [==============================] - 2s 51ms/step - loss: 8.8728e-04 - accuracy: 0.0462
# Epoch 11/100
# 34/34 [==============================] - 2s 50ms/step - loss: 8.5174e-04 - accuracy: 0.0462
# Epoch 12/100
# 34/34 [==============================] - 2s 47ms/step - loss: 7.9266e-04 - accuracy: 0.0462
# Epoch 13/100
# 34/34 [==============================] - 2s 50ms/step - loss: 8.1630e-04 - accuracy: 0.0462
# Epoch 14/100
# 34/34 [==============================] - 1s 44ms/step - loss: 7.8549e-04 - accuracy: 0.0462
# Epoch 15/100
# 34/34 [==============================] - 2s 50ms/step - loss: 8.0936e-04 - accuracy: 0.0462
# Epoch 16/100
# 34/34 [==============================] - 2s 45ms/step - loss: 7.3325e-04 - accuracy: 0.0462
# Epoch 17/100
# 34/34 [==============================] - 1s 41ms/step - loss: 7.6537e-04 - accuracy: 0.0462
# Epoch 18/100
# 34/34 [==============================] - 1s 41ms/step - loss: 7.3716e-04 - accuracy: 0.0462
# Epoch 19/100
# 34/34 [==============================] - 1s 34ms/step - loss: 6.7868e-04 - accuracy: 0.0462
# Epoch 20/100
# 34/34 [==============================] - 2s 45ms/step - loss: 6.8534e-04 - accuracy: 0.0462
# Epoch 21/100
# 34/34 [==============================] - 2s 49ms/step - loss: 6.9118e-04 - accuracy: 0.0462
# Epoch 22/100
# 34/34 [==============================] - 2s 45ms/step - loss: 6.3334e-04 - accuracy: 0.0462
# 34/34 [==============================] - 2s 50ms/step - loss: 1.6087e-04 - accuracy: 0.0462
# Epoch 80/100
# 34/34 [==============================] - 2s 48ms/step - loss: 1.5779e-04 - accuracy: 0.0462
# Epoch 81/100
# 34/34 [==============================] - 2s 51ms/step - loss: 1.5084e-04 - accuracy: 0.0462
# Epoch 82/100
# 34/34 [==============================] - 2s 51ms/step - loss: 1.6749e-04 - accuracy: 0.0462
# Epoch 83/100
# 34/34 [==============================] - 2s 51ms/step - loss: 1.4703e-04 - accuracy: 0.0462
# Epoch 84/100
# 34/34 [==============================] - 2s 51ms/step - loss: 1.5598e-04 - accuracy: 0.0462
# Epoch 85/100
# 34/34 [==============================] - 2s 48ms/step - loss: 1.4629e-04 - accuracy: 0.0462
# Epoch 86/100
# 34/34 [==============================] - 2s 50ms/step - loss: 1.4269e-04 - accuracy: 0.0462
# Epoch 87/100
# 34/34 [==============================] - 2s 51ms/step - loss: 1.2791e-04 - accuracy: 0.0462
# Epoch 88/100
# 34/34 [==============================] - 2s 48ms/step - loss: 1.2550e-04 - accuracy: 0.0462
# Epoch 89/100
# 34/34 [==============================] - 2s 49ms/step - loss: 1.2677e-04 - accuracy: 0.0462
# Epoch 90/100
# 34/34 [==============================] - 2s 45ms/step - loss: 1.1543e-04 - accuracy: 0.0462
# Epoch 91/100
# 34/34 [==============================] - 2s 47ms/step - loss: 1.2909e-04 - accuracy: 0.0462 0s - loss: 1.3090e-0
# Epoch 92/100
# 34/34 [==============================] - 2s 50ms/step - loss: 1.1354e-04 - accuracy: 0.0462
# Epoch 93/100
# 34/34 [==============================] - 2s 50ms/step - loss: 1.1174e-04 - accuracy: 0.0462
# Epoch 94/100
# 34/34 [==============================] - 2s 49ms/step - loss: 1.0354e-04 - accuracy: 0.0462
# Epoch 95/100
# 34/34 [==============================] - 2s 50ms/step - loss: 1.0685e-04 - accuracy: 0.0462
# Epoch 96/100
# 34/34 [==============================] - 2s 49ms/step - loss: 1.0686e-04 - accuracy: 0.0462
# Epoch 97/100
# 34/34 [==============================] - 2s 51ms/step - loss: 1.0337e-04 - accuracy: 0.0462
# Epoch 98/100
# 34/34 [==============================] - 2s 49ms/step - loss: 9.9464e-05 - accuracy: 0.0462
# Epoch 99/100
# 34/34 [==============================] - 2s 49ms/step - loss: 9.6093e-05 - accuracy: 0.0462
# Epoch 100/100
# 34/34 [==============================] - 2s 49ms/step - loss: 8.6781e-05 - accuracy: 0.0462
# LSTM Mean Absolute Error: 0.02518853072588534
# LSTM MSE: 0.0011588674790867135
# LSTM RMSE: 0.0340421426923558

# %%
def build_bilstm_model(X_train, y_train, X_test, y_test):
    # The Bidirectional LSTM architecture
    regressorBiLSTM = Sequential()    
    regressorBiLSTM.add(Bidirectional(LSTM(256, input_shape=(X_train.shape[1], X_train.shape[2]), dropout=0.2, return_sequences=True)))
    regressorBiLSTM.add(Bidirectional(LSTM(128, input_shape=(X_train.shape[1], X_train.shape[2]), dropout=0.2, return_sequences=True)))
    regressorBiLSTM.add(Bidirectional(LSTM(64, input_shape=(X_train.shape[1], X_train.shape[2]), dropout=0.2, return_sequences=False)))
    regressorBiLSTM.add(Dense(32,kernel_initializer="uniform",activation='relu'))        
    regressorBiLSTM.add(Dense(1,kernel_initializer="uniform",activation='linear'))
    regressorBiLSTM.add(Activation("linear"))

    regressorBiLSTM.compile(loss="mean_squared_error", optimizer="adam", metrics=['accuracy'])
    regressorBiLSTM.fit(X_train, y_train, epochs=100, batch_size=96)
    bilstm_pred = regressorBiLSTM.predict(X_test).squeeze()

    bilstm_MSE = mean_squared_error(y_test, bilstm_pred)
    bilstm_MAE = mean_absolute_error(y_test, bilstm_pred)
    bilstm_RMSE = np.sqrt(np.mean(np.power((np.array(y_test)-np.array(bilstm_pred)),2)))
    print('Bidirectional LSTM Mean Absolute Error: {}'.format(bilstm_MAE))
    print('Bidirectional LSTM MSE: {}'.format(bilstm_MSE))
    print('Bidirectional LSTM RMSE: {}'.format(bilstm_RMSE))

    return regressorBiLSTM, bilstm_pred, bilstm_MSE, bilstm_MAE, bilstm_RMSE

# %%
regressorBiLSTM, bilstm_pred, bilstm_MSE, bilstm_MAE, bilstm_RMSE = build_bilstm_model(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/100
# 34/34 [==============================] - 24s 97ms/step - loss: 0.0015 - accuracy: 0.0462
# Epoch 2/100
# 34/34 [==============================] - 3s 83ms/step - loss: 0.0011 - accuracy: 0.0462
# Epoch 3/100
# 34/34 [==============================] - 3s 89ms/step - loss: 0.0010 - accuracy: 0.0462
# Epoch 4/100
# 34/34 [==============================] - 3s 91ms/step - loss: 9.9780e-04 - accuracy: 0.0462
# Epoch 5/100
# 34/34 [==============================] - 3s 84ms/step - loss: 9.8841e-04 - accuracy: 0.0462
# Epoch 6/100
# 34/34 [==============================] - 3s 92ms/step - loss: 9.9357e-04 - accuracy: 0.0462
# Epoch 7/100
# 34/34 [==============================] - 3s 93ms/step - loss: 9.1567e-04 - accuracy: 0.0462
# Epoch 8/100
# 34/34 [==============================] - 3s 91ms/step - loss: 8.6819e-04 - accuracy: 0.0462
# Epoch 9/100
# 34/34 [==============================] - 3s 92ms/step - loss: 9.0154e-04 - accuracy: 0.0462
# Epoch 10/100
# 34/34 [==============================] - 3s 89ms/step - loss: 9.0655e-04 - accuracy: 0.0462
# Epoch 11/100
# 34/34 [==============================] - 3s 95ms/step - loss: 8.4349e-04 - accuracy: 0.0462
# Epoch 12/100
# 34/34 [==============================] - 3s 93ms/step - loss: 8.3883e-04 - accuracy: 0.0462
# Epoch 13/100
# 34/34 [==============================] - 3s 95ms/step - loss: 8.3240e-04 - accuracy: 0.0462
# Epoch 14/100
# 34/34 [==============================] - 3s 93ms/step - loss: 8.2598e-04 - accuracy: 0.0462
# Epoch 15/100
# 34/34 [==============================] - 3s 96ms/step - loss: 7.8812e-04 - accuracy: 0.0462
# Epoch 16/100
# 34/34 [==============================] - 3s 92ms/step - loss: 7.8779e-04 - accuracy: 0.0462
# Epoch 17/100
# 34/34 [==============================] - 3s 93ms/step - loss: 7.8769e-04 - accuracy: 0.0462
# Epoch 18/100
# 34/34 [==============================] - 3s 91ms/step - loss: 7.7252e-04 - accuracy: 0.0462
# Epoch 19/100
# 34/34 [==============================] - 3s 85ms/step - loss: 7.5511e-04 - accuracy: 0.0462
input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))
    regressorGRU.add(Dropout(0.2))
    regressorGRU.add(GRU(128, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))
    regressorGRU.add(Dropout(0.2))
    regressorGRU.add(GRU(64, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
    regressorGRU.add(Dropout(0.2))
    regressorGRU.add(Dense(32,kernel_initializer="uniform",activation='relu'))        
    regressorGRU.add(Dense(1,kernel_initializer="uniform",activation='linear'))
    regressorGRU.add(Activation("linear"))
    
    regressorGRU.compile(loss="mean_squared_error", optimizer="adam", metrics=['accuracy'])
    regressorGRU.fit(X_train, y_train, epochs=100, batch_size=96)
    gru_pred = regressorGRU.predict(X_test).squeeze()

    gru_MSE = mean_squared_error(y_test, gru_pred)
    gru_MAE = mean_absolute_error(y_test, gru_pred)
    gru_RMSE = np.sqrt(np.mean(np.power((np.array(y_test)-np.array(gru_pred)),2)))
    print('GRU Mean Absolute Error: {}'.format(gru_MAE))
    print('GRU MSE: {}'.format(gru_MSE))
    print('GRU RMSE: {}'.format(gru_RMSE))

    return regressorGRU, gru_pred, gru_MSE, gru_MAE, gru_RMSE

# %%
regressorGRU, gru_pred, gru_MSE, gru_MAE, gru_RMSE = build_gru_model(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/100
# 34/34 [==============================] - 11s 41ms/step - loss: 0.0015 - accuracy: 0.0462
# Epoch 2/100
# 34/34 [==============================] - 1s 29ms/step - loss: 0.0012 - accuracy: 0.0462
# Epoch 3/100
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0011 - accuracy: 0.0462
# Epoch 4/100
# 34/34 [==============================] - 1s 39ms/step - loss: 0.0010 - accuracy: 0.0462
# Epoch 5/100
# 34/34 [==============================] - 1s 40ms/step - loss: 9.8332e-04 - accuracy: 0.0462
# Epoch 6/100
# 34/34 [==============================] - 1s 39ms/step - loss: 9.0878e-04 - accuracy: 0.0462
# Epoch 7/100
# 34/34 [==============================] - 1s 39ms/step - loss: 8.5226e-04 - accuracy: 0.0462
# Epoch 8/100
# 34/34 [==============================] - 1s 38ms/step - loss: 8.8773e-04 - accuracy: 0.0462
# Epoch 9/100
# 34/34 [==============================] - 1s 40ms/step - loss: 8.7338e-04 - accuracy: 0.0462
# Epoch 10/100
# 34/34 [==============================] - 1s 39ms/step - loss: 8.4144e-04 - accuracy: 0.0462
# Epoch 11/100
# 34/34 [==============================] - 1s 38ms/step - loss: 7.8882e-04 - accuracy: 0.0462
# Epoch 12/100
# 34/34 [==============================] - 1s 39ms/step - loss: 7.6527e-04 - accuracy: 0.0462
# Epoch 13/100
# 34/34 [==============================] - 1s 40ms/step - loss: 6.8825e-04 - accuracy: 0.0462
# Epoch 14/100
# 34/34 [==============================] - 1s 40ms/step - loss: 7.2765e-04 - accuracy: 0.0462
# Epoch 15/100
# 34/34 [==============================] - 1s 28ms/step - loss: 7.2566e-04 - accuracy: 0.0462
# Epoch 16/100
# 34/34 [==============================] - 1s 37ms/step - loss: 6.5490e-04 - accuracy: 0.0462
# Epoch 17/100
# 34/34 [==============================] - 1s 41ms/step - loss: 6.2572e-04 - accuracy: 0.0462
# Epoch 18/100
# 34/34 [==============================] - 1s 37ms/step - loss: 6.2216e-04 - accuracy: 0.0462
100
# 34/34 [==============================] - 1s 40ms/step - loss: 1.4685e-04 - accuracy: 0.0462
# Epoch 80/100
# 34/34 [==============================] - 1s 40ms/step - loss: 1.4199e-04 - accuracy: 0.0462
# Epoch 81/100
# 34/34 [==============================] - 1s 35ms/step - loss: 1.3639e-04 - accuracy: 0.0462
# Epoch 82/100
# 34/34 [==============================] - 1s 25ms/step - loss: 1.2916e-04 - accuracy: 0.0462
# Epoch 83/100
# 34/34 [==============================] - 1s 37ms/step - loss: 1.2996e-04 - accuracy: 0.0462
# Epoch 84/100
# 34/34 [==============================] - 1s 40ms/step - loss: 1.3786e-04 - accuracy: 0.0462
# Epoch 85/100
# 34/34 [==============================] - 1s 36ms/step - loss: 1.2888e-04 - accuracy: 0.0462
# Epoch 86/100
# 34/34 [==============================] - 1s 39ms/step - loss: 1.1349e-04 - accuracy: 0.0462
# Epoch 87/100
# 34/34 [==============================] - 1s 37ms/step - loss: 1.1402e-04 - accuracy: 0.0462
# Epoch 88/100
# 34/34 [==============================] - 1s 37ms/step - loss: 1.1137e-04 - accuracy: 0.0462
# Epoch 89/100
# 34/34 [==============================] - 1s 34ms/step - loss: 1.0680e-04 - accuracy: 0.0462
# Epoch 90/100
# 34/34 [==============================] - 1s 33ms/step - loss: 1.1822e-04 - accuracy: 0.0462
# Epoch 91/100
# 34/34 [==============================] - 1s 30ms/step - loss: 1.0501e-04 - accuracy: 0.0462
# Epoch 92/100
# 34/34 [==============================] - 1s 37ms/step - loss: 1.0039e-04 - accuracy: 0.0462
# Epoch 93/100
# 34/34 [==============================] - 1s 38ms/step - loss: 1.0901e-04 - accuracy: 0.0462
# Epoch 94/100
# 34/34 [==============================] - 1s 39ms/step - loss: 1.0316e-04 - accuracy: 0.0462
# Epoch 95/100
# 34/34 [==============================] - 1s 41ms/step - loss: 1.0189e-04 - accuracy: 0.0462
# Epoch 96/100
# 34/34 [==============================] - 1s 40ms/step - loss: 1.0532e-04 - accuracy: 0.0462
# Epoch 97/100
# 34/34 [==============================] - 1s 40ms/step - loss: 1.0822e-04 - accuracy: 0.0462
# Epoch 98/100
# 34/34 [==============================] - 1s 39ms/step - loss: 9.5510e-05 - accuracy: 0.0462
# Epoch 99/100
# 34/34 [==============================] - 1s 40ms/step - loss: 9.3102e-05 - accuracy: 0.0462
# Epoch 100/100
# 34/34 [==============================] - 1s 40ms/step - loss: 9.4668e-05 - accuracy: 0.0462
# GRU Mean Absolute Error: 0.026140834244563888
# GRU MSE: 0.001223855967927597
# GRU RMSE: 0.03498365286712634

# %%
def build_rnn_model(X_train, y_train, X_test, y_test):
    # The RNN architecture
    regressorRNN = Sequential()
    regressorRNN.add(SimpleRNN(256, return_sequences=True))
    regressorRNN.add(SimpleRNN(128, return_sequences=True))
    regressorRNN.add(SimpleRNN(64, return_sequences=True))
    regressorRNN.add(SimpleRNN(32))
    regressorRNN.add(Dense(1))
    regressorRNN.add(Activation("linear"))

    regressorRNN.compile(loss="mean_squared_error", optimizer="adam", metrics=['accuracy'])
    regressorRNN.fit(X_train, y_train, epochs=100, batch_size=96)
    rnn_pred = regressorRNN.predict(X_test).squeeze()

    rnn_MSE = mean_squared_error(y_test, rnn_pred)
    rnn_MAE = mean_absolute_error(y_test, rnn_pred)
    rnn_RMSE = np.sqrt(np.mean(np.power((np.array(y_test)-np.array(rnn_pred)),2)))
    print('RNN Mean Absolute Error: {}'.format(rnn_MAE))
    print('RNN MSE: {}'.format(rnn_MSE))
    print('RNN RMSE: {}'.format(rnn_RMSE))

    return regressorRNN, rnn_pred, rnn_MSE, rnn_MAE, rnn_RMSE

# %%
regressorRNN, rnn_pred, rnn_MSE, rnn_MAE, rnn_RMSE = build_rnn_model(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/100
# 34/34 [==============================] - 6s 16ms/step - loss: 0.1691 - accuracy: 0.0443
# Epoch 2/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0020 - accuracy: 0.0462
# Epoch 3/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0014 - accuracy: 0.0462
# Epoch 4/100
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0013 - accuracy: 0.0462
# Epoch 5/100
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0013 - accuracy: 0.0462
# Epoch 6/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0012 - accuracy: 0.0462
# Epoch 7/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0012 - accuracy: 0.0462
# Epoch 8/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0011 - accuracy: 0.0462
# Epoch 9/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0011 - accuracy: 0.0462
# Epoch 10/100
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0011 - accuracy: 0.0462
# Epoch 11/100
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0011 - accuracy: 0.0462
# Epoch 12/100
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0011 - accuracy: 0.0462
# Epoch 13/100
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0010 - accuracy: 0.0462ETA: 0s - loss: 0.0010 - accuracy:
# Epoch 14/100
# 34/34 [==============================] - 0s 9ms/step - loss: 0.0010 - accuracy: 0.0462
# Epoch 15/100
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0010 - accuracy: 0.0462
# Epoch 16/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0010 - accuracy: 0.0462
# Epoch 17/100
# 34/34 [==============================] - 0s 10ms/step - loss: 9.9572e-04 - accuracy: 0.0462
# Epoch 18/100
# 34/34 [==============================] - 1s 17ms/step - loss: 9.9520e-04 - accuracy: 0.0462 0s - loss: 9.7726e-04 - accuracy:  - ETA: 0s - loss: 9.6127e-04 - accuracy
# Epoch 19/100
# 34/34 [==============================] - 1s 15ms/step - loss: 9.8382e-04 - accuracy: 0.0462
# Epoch 20/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0010 - accuracy: 0.0462
# Epoch 21/100
# 34/34 [==============================] - 0s 13ms/step - loss: 9.8076e-04 - accuracy: 0.0462
# Epoch 22/100
# 34/34 [==============================] - 1s 16ms/step - loss: 9.4450e-04 - accuracy: 0.0462
# Epoch 23/100
# 34/34 [==============================] - 0s 12ms/step - loss: 9.4306e-04 - accuracy: 0.0462
# Epoch 24/100
# 34/34 [==============================] - 1s 15ms/step - loss: 9.3135e-04 - accuracy: 0.0462
# Epoch 25/100
# 34/34 [==============================] - 1s 15ms/step - loss: 9.2011e-04 - accuracy: 0.0462
# Epoch 26/100
# 34/34 [==============================] - 1s 16ms/step - loss: 9.1545e-04 - accuracy: 0.0462
# Epoch 27/100
# 34/34 [==============================] - 1s 16ms/step - loss: 8.9897e-04 - accuracy: 0.0462
# Epoch 28/100
# 34/34 [==============================] - 1s 16ms/step - loss: 9.1078e-04 - accuracy: 0.0462
# Epoch 29/100
# 34/34 [==============================] - 1s 16ms/step - loss: 9.3615e-04 - accuracy: 0.0462
# Epoch 30/100
# 34/34 [==============================] - 1s 16ms/step - loss: 8.8917e-04 - accuracy: 0.0462
# Epoch 31/100
# 34/34 [==============================] - 1s 15ms/step - loss: 8.8976e-04 - accuracy: 0.0462
# Epoch 32/100
# 34/34 [==============================] - 1s 16ms/step - loss: 8.7501e-04 - accuracy: 0.0462
# Epoch 33/100
# 34/34 [==============================] - 0s 14ms/step - loss: 8.7052e-04 - accuracy: 0.0462
# Epoch 34/100
# 34/34 [==============================] - 0s 14ms/step - loss: 8.8489e-04 - accuracy: 0.0462
# Epoch 35/100
# 34/34 [==============================] - 0s 14ms/step - loss: 8.5617e-04 - accuracy: 0.0462
# Epoch 36/100
# 34/34 [==============================] - 1s 16ms/step - loss: 8
100
# 34/34 [==============================] - 1s 16ms/step - loss: 6.8954e-04 - accuracy: 0.0462
# Epoch 82/100
# 34/34 [==============================] - 1s 15ms/step - loss: 6.0127e-04 - accuracy: 0.0462
# Epoch 83/100
# 34/34 [==============================] - 1s 16ms/step - loss: 6.4386e-04 - accuracy: 0.0462
# Epoch 84/100
# 34/34 [==============================] - 1s 15ms/step - loss: 6.3864e-04 - accuracy: 0.0462
# Epoch 85/100
# 34/34 [==============================] - 1s 16ms/step - loss: 5.7972e-04 - accuracy: 0.0462
# Epoch 86/100
# 34/34 [==============================] - 1s 16ms/step - loss: 5.9987e-04 - accuracy: 0.0462
# Epoch 87/100
# 34/34 [==============================] - 1s 15ms/step - loss: 5.4238e-04 - accuracy: 0.0462
# Epoch 88/100
# 34/34 [==============================] - 1s 16ms/step - loss: 5.4198e-04 - accuracy: 0.0462
# Epoch 89/100
# 34/34 [==============================] - 0s 15ms/step - loss: 5.4709e-04 - accuracy: 0.0462
# Epoch 90/100
# 34/34 [==============================] - 1s 15ms/step - loss: 5.1679e-04 - accuracy: 0.0462
# Epoch 91/100
# 34/34 [==============================] - 0s 14ms/step - loss: 5.3370e-04 - accuracy: 0.0462
# Epoch 92/100
# 34/34 [==============================] - 1s 16ms/step - loss: 5.6336e-04 - accuracy: 0.0462
# Epoch 93/100
# 34/34 [==============================] - 1s 16ms/step - loss: 5.3665e-04 - accuracy: 0.0462
# Epoch 94/100
# 34/34 [==============================] - 1s 16ms/step - loss: 6.1451e-04 - accuracy: 0.0462
# Epoch 95/100
# 34/34 [==============================] - 1s 16ms/step - loss: 4.8768e-04 - accuracy: 0.0462
# Epoch 96/100
# 34/34 [==============================] - 1s 16ms/step - loss: 4.8755e-04 - accuracy: 0.0462
# Epoch 97/100
# 34/34 [==============================] - 1s 16ms/step - loss: 5.2369e-04 - accuracy: 0.0462
# Epoch 98/100
# 34/34 [==============================] - 0s 14ms/step - loss: 4.8898e-04 - accuracy: 0.0462
# Epoch 99/100
# 34/34 [==============================] - 1s 16ms/step - loss: 4.6770e-04 - accuracy: 0.0462
# Epoch 100/100
# 34/34 [==============================] - 1s 16ms/step - loss: 4.5769e-04 - accuracy: 0.0462
# RNN Mean Absolute Error: 0.02453061768925531
# RNN MSE: 0.0010105227079771797
# RNN RMSE: 0.031788719822873956

# %%
lstm_pred = test[target_col].values[:-window_len] * (lstm_pred + 1)
lstm_pred = pd.Series(index=targets.index, data=lstm_pred)

bilstm_pred = test[target_col].values[:-window_len] * (bilstm_pred + 1)
bilstm_pred = pd.Series(index=targets.index, data=bilstm_pred)

gru_pred = test[target_col].values[:-window_len] * (gru_pred + 1)
gru_pred = pd.Series(index=targets.index, data=gru_pred)

rnn_pred = test[target_col].values[:-window_len] * (rnn_pred + 1)
rnn_pred = pd.Series(index=targets.index, data=rnn_pred)

# %%
line_plot(targets, lstm_pred, 'actual', 'prediction', lw=3)

# %%
line_plot(targets, bilstm_pred, 'actual', 'prediction', lw=3)

# %%
line_plot(targets, gru_pred, 'actual', 'prediction', lw=3)

# %%
line_plot(targets, rnn_pred, 'actual', 'prediction', lw=3)

# %%
result = pd.concat([test[target_col], lstm_pred, bilstm_pred, gru_pred, rnn_pred], axis=1)
result.rename(columns={result.columns[0]:'Close Test'}, inplace=True)
result.rename(columns={result.columns[1]:'Close LSTM'}, inplace=True)
result.rename(columns={result.columns[2]:'Close BiLSTM'}, inplace=True)
result.rename(columns={result.columns[3]:'Close GRU'}, inplace=True)
result.rename(columns={result.columns[4]:'Close RNN'}, inplace=True)

# %%
result = result.dropna()
result
# Out:
#             Close Test   Close LSTM  Close BiLSTM    Close GRU    Close RNN
# Date
# 2015-12-23      3258.0  3290.350565   3278.799573  3309.726177  3235.371373
# 2015-12-28      3279.0  3169.093677   3209.028720  3197.924858  3158.407294
# 2015-12-29      3126.0  3274.752515   3211.240147  3217.588966  3203.715410
# 2015-12-30      3279.0  3222.015336   3200.172603  3209.965095  3099.033952
# 2015-12-31      3270.0  3261.320800   3242.999424  3231.629892  3227.579579
# ...                ...          ...           ...          ...          ...
# 2021-11-05      4870.0  5180.136764   4943.957591  5016.286290  4856.114078
# 2021-11-10      4850.0  4963.772392   4895.430565  4847.193718  4865.887070
# 2021-11-12      4700.0  4844.751129   4851.478946  4840.376154  4804.977131
# 2021-11-16      4800.0  4900.522208   4789.820492  4883.049846  4727.719188
# 2021-11-17      4800.0  4823.927741   4819.164585  4822.110605  4816.477280
#
# [797 rows x 5 columns]

# %%
#result.to_excel("result_lstm_gru_rnn.xlsx")

# %%
lstm_MAPE = mean_absolute_percentage_error(result["Close Test"], result["Close LSTM"])
bilstm_MAPE = mean_absolute_percentage_error(result["Close Test"], result["Close BiLSTM"])
gru_MAPE = mean_absolute_percentage_error(result["Close Test"], result["Close GRU"])
rnn_MAPE = mean_absolute_percentage_error(result["Close Test"], result["Close RNN"])

# %%
cnames=['LSTM', 'BiLSTM', 'GRU', 'RNN']
finalResult = pd.DataFrame(columns=cnames, index=["MAE", "MSE", "RMSE", "MAPE"])

# %%
finalResult["LSTM"]["MAE"] = lstm_MAE
finalResult["LSTM"]["MSE"] = lstm_MSE
finalResult["LSTM"]["RMSE"] = lstm_RMSE
finalResult["LSTM"]["MAPE"] = lstm_MAPE

finalResult["BiLSTM"]["MAE"] = bilstm_MAE
finalResult["BiLSTM"]["MSE"] = bilstm_MSE
finalResult["BiLSTM"]["RMSE"] = bilstm_RMSE
finalResult["BiLSTM"]["MAPE"] = bilstm_MAPE

finalResult["GRU"]["MAE"] = gru_MAE
finalResult["GRU"]["MSE"] = gru_MSE
finalResult["GRU"]["RMSE"] = gru_RMSE
finalResult["GRU"]["MAPE"] = gru_MAPE

finalResult["RNN"]["MAE"] = rnn_MAE
finalResult["RNN"]["MSE"] = rnn_MSE
finalResult["RNN"]["RMSE"] = rnn_RMSE
finalResult["RNN"]["MAPE"] = rnn_MAPE

# %%
finalResult
# Out:
#           LSTM    BiLSTM       GRU       RNN
# MAE   0.025189  0.022415  0.026141  0.024531
# MSE   0.001159  0.000935  0.001224  0.001011
# RMSE  0.034042  0.030581  0.034984  0.031789
# MAPE  0.025444  0.022581  0.026296  0.024605

# %%
finalResult.to_excel("finalResult_lstm_bilstm_gru_rnn_WAFA-ASSURANCE.xlsx")
