# %%
#import packages
from sklearn.metrics import classification_report, accuracy_score
from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout, LSTM, Bidirectional, GRU, SimpleRNN, TimeDistributed, Embedding
from keras.layers.convolutional import Conv1D, MaxPooling1D
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
from sklearn import preprocessing
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score
from sklearn.metrics import accuracy_score
import seaborn as sns
import pandas as pd
import numpy as np
from ta import add_all_ta_features # Library that does financial technical analysis 

#to plot within notebook
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

#for normalizing data
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))

# %%
# Importing the training set
df = pd.read_csv('Data/BCP.csv', index_col="Date", parse_dates=True)

# Add all technical analysis to the dataframe we've already loaded
df = add_all_ta_features(df, "Open", "High", "Low", "Close", "Volume", fillna=True)

print(df)
# Out:
# C:\Users\bentaleb.khalid\Anaconda3\lib\site-packages\ta\trend.py:768: RuntimeWarning: invalid value encountered in double_scalars
#   dip[i] = 100 * (self._dip[i] / self._trs[i])
# C:\Users\bentaleb.khalid\Anaconda3\lib\site-packages\ta\trend.py:772: RuntimeWarning: invalid value encountered in double_scalars
#   din[i] = 100 * (self._din[i] / self._trs[i])
#               Open    High     Low   Close    Volume    volume_adi  \
# Date
# 2004-07-20   36.68   36.68   36.68   36.68  60516.22  0.000000e+00
# 2004-07-21   38.35   38.35   38.35   38.35  16049.06  0.000000e+00
# 2004-07-27   38.64   38.64   38.64   38.64  49782.77  0.000000e+00
# 2004-07-29   37.17   37.27   37.17   37.22  44344.49 -3.150866e-09
# 2004-02-08   36.78   37.17   36.78   36.78  82432.91 -8.243291e+04
# ...            ...     ...     ...     ...       ...           ...
# 2022-06-06  264.85  264.85  264.85  264.85      1.00  4.653368e+07
# 2022-07-06  255.00  264.50  255.00  258.00  42275.00  4.651811e+07
# 2022-08-06  258.00  262.00  256.75  262.00  20410.00  4.653852e+07
# 2022-09-06  262.00  262.00  260.05  262.00  19632.00  4.655815e+07
# 2022-10-06  262.00  262.00  258.00  260.00  15272.00  4.655815e+07
#
#              volume_obv    volume_cmf     volume_fi  volume_mfi  ...  \
# Date                                                             ...
# 2004-07-20     60516.22  0.000000e+00      0.000000   50.000000  ...
# 2004-07-21     76565.28  0.000000e+00  26801.930200  100.000000  ...
# 2004-07-27    126348.05  0.000000e+00  25035.512071  100.000000  ...
# 2004-07-29     82003.56 -1.845930e-14  12463.413804   60.604687  ...
# 2004-02-08      -429.35 -3.256603e-01   5501.428918   35.108152  ...
# ...                 ...           ...           ...         ...  ...
# 2022-06-06  69361699.15 -5.921673e-01  74167.431039   74.432667  ...
# 2022-07-06  69319424.15 -5.703050e-01  22202.976605   68.647962  ...
# 2022-08-06  69339834.15 -5.020806e-01  30693.979947   69.216019  ...
# 2022-09-06  69359466.15 -4.460287e-01  26309.125669   73.739904  ...
# 2022-10-06  69344194.15 -4.330046e-01  18187.250573   71.633343  ...
#
#             momentum_wr  momentum_ao  momentum_kama  momentum_roc  \
# Date
# 2004-07-20   -50.000000     0.000000      36.680000      0.000000
# 2004-07-21    -0.000000     0.000000      37.316952      0.000000
# 2004-07-27    -0.000000     0.000000      37.849663      0.000000
# 2004-07-29   -72.448980     0.000000      37.589350      0.000000
# 2004-02-08   -94.897959     0.000000      37.246376      0.000000
# ...                 ...          ...            ...           ...
# 2022-06-06    -5.250597    -4.815441     266.458796      3.054475
# 2022-07-06   -37.947494    -2.138971     266.458796      1.976285
# 2022-08-06   -18.854415    -0.413824     266.458796      2.745098
# 2022-09-06   -18.854415     1.303088     266.458796      3.536850
# 2022-10-06   -28.400955     1.419853     266.458796      1.960784
#
#             momentum_ppo  momentum_ppo_signal  momentum_ppo_hist  others_dr  \
# Date
# 2004-07-20      0.000000             0.000000           0.000000 -80.213412
# 2004-07-21     -6.199042            -1.239808          -4.959234   4.552890
# 2004-07-27     -6.343567            -2.260560          -4.083007   0.756193
# 2004-07-29     -7.219102            -3.252268          -3.966833  -3.674948
# 2004-02-08     -2.213724            -3.044559           0.830835  -1.182160
# ...                  ...                  ...                ...        ...
# 2022-06-06     48.057301            24.366111          23.691190   2.655039
# 2022-07-06     41.002478            27.693384          13.309094  -2.586370
# 2022-08-06     31.964138            28.547535           3.416604   1.550388
# 2022-09-06     24.023199            27.642668          -3.619468   0.000000
# 2022-10-06     16.358477            25.385830          -9.027352  -0.763359
#
#             others_dlr   others_cr
# Date
# 2004-07-20    0.000000    0.000000
# 2004-07-21    4.452288    4.552890
# 2004-07-27    0.753348    5.343511
# 2004-07-29   -3.744176    1.472192
# 2004-02-08   -1.189203    0.272628
# ...                ...         ...
# 2022-06-06    2.620404  622.055616
# 2022-07-06   -2.620404  603.380589
# 2022-08-06    1.538492  614.285714
# 2022-09-06    0.000000  614.285714
# 2022-10-06   -0.766287  608.833152
#
# [4396 rows x 88 columns]

# %%
# Visualize Close stock prices
df.plot.line(y="Close", use_index=True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#how many days data will be used to create series to train RNN
SERIES_LENGTH=5

# %%
def scale_data(df):
    for column in df.columns:
        df[column] = preprocessing.scale(df[column].values)
    return df

# %%
import numpy as np
def process_data(df):
    df["Label"] = df.rolling(5).apply(lambda x: x.iloc[1] > x.iloc[0])["Close"]

    #Dropping any Nan values
    df.dropna(inplace=True)
    
    sequence=[]
    # We want to scale the data except the label part since it is already 0 and 1
    temp=df.loc[:, df.columns != 'Label']
#     temp=scale_data(temp)
    temp = scaler.fit_transform(temp)
    # print(f"temp{temp[:30]}")
    for i in range (len(temp)-SERIES_LENGTH):
       sequence.append([np.array(temp[i:i+SERIES_LENGTH]),df.iloc[i+SERIES_LENGTH,-1]]) # iloc part is to take last column data i.e. labels

    np.random.shuffle(sequence)

    #Now we will count the sells and buys to balance the data
    # Algorithm : whichever count is less, we will take up the data upto that
    X=[]
    y=[]
    buy=[]
    sell=[]
    for seq ,label in sequence:
        if label == 0:
            sell.append([seq,label])
        else:
            buy.append([seq,label])
            
    # print(f"buy :{buy[:10]}")
    # print(f"sell :{sell[:10]}")
    
    buys=len(buy)
    sells=len(sell)
    print(f"original buys:{buys} original sells:{sells}")
    if(buys<sells):
        buy=buy[:buys]
        sell=sell[:buys]
    else:
        buy=buy[:sells]
        sell=sell[:sells]

    print(f"buys:{len(buy)} sells:{len(sell)}")
    # Concat the buys an sells and shuffle it out again
    sequence=buy+sell

    np.random.shuffle(sequence)


    for seq ,label in sequence:
        X.append(seq)
        y.append(label)

    return np.array(X),np.array(y)

# %%
df.shape
# Out:
# (4396, 88)

# %%
process_data(df)
# Out:
# original buys:1943 original sells:2444
# buys:1943 sells:1943
# (array([[[0.30262718, 0.30261654, 0.31031433, ..., 0.64115106,
#           0.66114032, 0.30895966],
#          [0.30998061, 0.30359651, 0.3108246 , ..., 0.55048255,
#           0.57220882, 0.30732213],
#          [0.30342937, 0.30836573, 0.31113077, ..., 0.68526535,
#           0.70390878, 0.31547639],
#          [0.30998061, 0.31636886, 0.31779834, ..., 0.68356183,
#           0.70226323, 0.32366407],
#          [0.32060967, 0.31316761, 0.32613281, ..., 0.52954088,
#           0.55146796, 0.320389  ]],
#
#         [[0.53405976, 0.5217718 , 0.54585658, ..., 0.55362802,
#           0.57531757, 0.53380343],
#          [0.53740223, 0.52503838, 0.5492584 , ..., 0.60277526,
#           0.62367032, 0.53714534],
#          [0.53740223, 0.52993826, 0.5492584 , ..., 0.61745693,
#           0.6380348 , 0.54215821],
#          [0.54241594, 0.54610786, 0.55436114, ..., 0.62300324,
#           0.6434518 , 0.54783945],
#          [0.54308443, 0.53320485, 0.5550415 , ..., 0.55251729,
#           0.57422   , 0.54550012]],
#
#         [[0.82719433, 0.80906804, 0.84028439, ..., 0.58217686,
#           0.60345522, 0.82772449],
#          [0.82819707, 0.81070134, 0.8401143 , ..., 0.58318567,
#           0.60444694, 0.82939545],
#          [0.8198409 , 0.80433149, 0.83671248, ..., 0.51266371,
#           0.53469707, 0.81953681],
#          [0.81666555, 0.80759808, 0.83348075, ..., 0.57294952,
#           0.59437608, 0.81953681],
#          [0.83270941, 0.81364126, 0.83671248, ..., 0.57294952,
#           0.59437608, 0.81953681]],
#
#         ...,
#
#         [[0.0794505 , 0.07748342, 0.08303851, ..., 0.50863073,
#           0.53068211, 0.07927013],
#          [0.08108831, 0.08150132, 0.08484148, ..., 0.66747164,
#           0.68669683, 0.0823781 ],
#          [0.08125543, 0.0822853 , 0.08501157, ..., 0.60294668,
#           0.62383824, 0.08338068],
#          [0.07995187, 0.08627054, 0.08368486, ..., 0.71817693,
#           0.7356069 , 0.08825987],
#          [0.08519955, 0.09218306, 0.08902572, ..., 0.69228023,
#           0.71067994, 0.09237042]],
#
#         [[0.29363594, 0.28919087, 0.2955164 , ..., 0.4202012 ,
#           0.44192341, 0.28787221],
#          [0.29771375, 0.29079149, 0.28534494, ..., 0.49955776,
#           0.52163925, 0.2827925 ],
#          [0.2846447 , 0.27801914, 0.28701184, ..., 0.59691505,
#           0.61792651, 0.28443004],
#          [0.2815362 , 0.2812204 , 0.28884882, ..., 0.56564362,
#           0.58717719, 0.28392875],
#          [0.28628251, 0.29062816, 0.29252279, ..., 0.63049575,
#           0.6507614 , 0.28787221]],
#
#         [[0.90356976, 0.88289289, 0.92175806, ..., 0.53530062,
#           0.55718006, 0.90308458],
#          [0.9067451 , 0.88926273, 0.91155259, ..., 0.61084692,
#           0.63157211, 0.90976841],
#          [0.89571495, 0.87537974, 0.91155259, ..., 0.47882728,
#           0.50092313, 0.89305885],
#          [0.89354235, 0.87619639, 0.91155259, ..., 0.57294952,
#           0.59437608, 0.89305885],
#          [0.89370947, 0.87325646, 0.91155259, ..., 0.57390642,
#           0.5953183 , 0.89322595]]]),
#  array([1., 1., 0., ..., 1., 1., 0.]))

# %%
df['Label'].value_counts()
# Out:
# 0.0    2447
# 1.0    1945
# Name: Label, dtype: int64

# %%
# Plot target variable
plt.figure(figsize=(8,4))
sns.countplot('Label', data=df)
plt.title('Target Variable Count')
plt.show()
# Out:
# C:\Users\bentaleb.khalid\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
training_size=0.8

# %%
spilt_point=int(training_size*len(df))

# %%
#splitting data for training and testing in ratio 80:20
train_df=df[:spilt_point]
test_df=df[spilt_point:]

# %%
import warnings
warnings.filterwarnings("ignore")

train_x,train_y=process_data(train_df)

test_x,test_y=process_data(test_df)

# %%
print('X_train :',train_x.shape)
print('y_train :',train_y.shape)
print('X_test :',test_x.shape)
print('y_test :',test_y.shape)

# %%
def build_model_LSTM():

    model=Sequential()
    
    model.add(Conv1D(512, kernel_size=4, activation='relu', input_shape=(train_x.shape[1:])))
    model.add(MaxPooling1D(2))
    
    model.add(LSTM(256, input_shape=(train_x.shape[1:]), return_sequences=True))
    model.add(Dropout(0.2))

    model.add(LSTM(128, input_shape=(train_x.shape[1:]), return_sequences=True))
    model.add(Dropout(0.2))

    model.add(LSTM(64, input_shape=(train_x.shape[1:]), return_sequences=False))
    model.add(Dropout(0.2))

    model.add(Dense(32, kernel_initializer="uniform", activation='tanh'))
    model.add(Dense(1, kernel_initializer="uniform", activation='sigmoid'))


    model.compile(loss='binary_crossentropy',optimizer="adam",metrics=['accuracy']) 
    history=model.fit(train_x, train_y, batch_size=96, epochs=100)
    score=model.evaluate(test_x,test_y)
    lstm_pred=model.predict(test_x).squeeze() > 0.5
    
    print("Validation accuracy percentage",score[1])
    print("Validation loss percentage",score[0])
    print("Precision score", precision_score(test_y, lstm_pred, average='macro'))
    print("Accuracy score", accuracy_score(test_y, lstm_pred, normalize=True))
    
    return model, lstm_pred

# %%
model_LSTM, lstm_pred = build_model_LSTM()

# %%
mat = confusion_matrix(test_y, lstm_pred)
labels = ['Legitimate', 'Fraudulent']
 
sns.heatmap(mat, square=True, annot=True, fmt='d', cbar=False, cmap='Blues',
            xticklabels=labels, yticklabels=labels)
 
plt.xlabel('Predicted label')
plt.ylabel('Actual label')

# %%
print(classification_report(test_y, lstm_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.81      0.87       390
#          1.0       0.83      0.95      0.89       390
#
#     accuracy                           0.88       780
#    macro avg       0.89      0.88      0.88       780
# weighted avg       0.89      0.88      0.88       780

# %%
def build_model_GRU():

    model=Sequential()
    
#     model.add(Conv1D(256, kernel_size=4, activation='relu', input_shape=(train_x.shape[1:])))
#     model.add(MaxPooling1D(2))
    
    model.add(GRU(256, input_shape=(train_x.shape[1:]), return_sequences=True))
    model.add(Dropout(0.2))

    model.add(GRU(128, input_shape=(train_x.shape[1:]), return_sequences=True))
    model.add(Dropout(0.2))

    model.add(GRU(64, input_shape=(train_x.shape[1:]), return_sequences=False))
    model.add(Dropout(0.2))

    model.add(Dense(32, kernel_initializer="uniform", activation='tanh'))
    model.add(Dense(1, kernel_initializer="uniform", activation='sigmoid'))


    model.compile(loss='binary_crossentropy',optimizer="adam",metrics=['accuracy'])
    history=model.fit(train_x, train_y, batch_size=96, epochs=100, validation_data=(test_x,test_y))
    score=model.evaluate(test_x,test_y)
    gru_pred=model.predict(test_x) > 0.5

    print("Validation accuracy percentage",score[1])
    print("Validation loss percentage",score[0])
    print("Precision score", precision_score(test_y, gru_pred, average='macro'))
    print("Accuracy score", accuracy_score(test_y, gru_pred, normalize=True))
    
    return model, gru_pred

# %%
model_GRU, gru_pred = build_model_GRU()
# Out:
# Epoch 1/100
# 33/33 [==============================] - 7s 54ms/step - loss: 0.6911 - accuracy: 0.5175 - val_loss: 0.6771 - val_accuracy: 0.6051
# Epoch 2/100
# 33/33 [==============================] - 1s 19ms/step - loss: 0.6307 - accuracy: 0.6495 - val_loss: 0.6169 - val_accuracy: 0.6628
# Epoch 3/100
# 33/33 [==============================] - 1s 22ms/step - loss: 0.5775 - accuracy: 0.7003 - val_loss: 0.5575 - val_accuracy: 0.7372
# Epoch 4/100
# 33/33 [==============================] - 1s 25ms/step - loss: 0.5098 - accuracy: 0.7495 - val_loss: 0.5234 - val_accuracy: 0.7244
# Epoch 5/100
# 33/33 [==============================] - 1s 25ms/step - loss: 0.4347 - accuracy: 0.8006 - val_loss: 0.2941 - val_accuracy: 0.8808
# Epoch 6/100
# 33/33 [==============================] - 1s 25ms/step - loss: 0.3039 - accuracy: 0.8725 - val_loss: 0.2957 - val_accuracy: 0.8756
# Epoch 7/100
# 33/33 [==============================] - 1s 25ms/step - loss: 0.2694 - accuracy: 0.8838 - val_loss: 0.4095 - val_accuracy: 0.8128
# Epoch 8/100
# 33/33 [==============================] - 1s 25ms/step - loss: 0.2743 - accuracy: 0.8783 - val_loss: 0.3744 - val_accuracy: 0.8346
# Epoch 9/100
# 33/33 [==============================] - 1s 25ms/step - loss: 0.2544 - accuracy: 0.8919 - val_loss: 0.2961 - val_accuracy: 0.8692
# Epoch 10/100
# 33/33 [==============================] - 1s 25ms/step - loss: 0.2167 - accuracy: 0.9081 - val_loss: 0.2441 - val_accuracy: 0.8859
# Epoch 11/100
# 33/33 [==============================] - 1s 25ms/step - loss: 0.2092 - accuracy: 0.9149 - val_loss: 0.2981 - val_accuracy: 0.8654
# Epoch 12/100
# 33/33 [==============================] - 1s 25ms/step - loss: 0.1929 - accuracy: 0.9201 - val_loss: 0.2100 - val_accuracy: 0.9154
# Epoch 13/100
# 33/33 [==============================] - 1s 27ms/step - loss: 0.1898 - accuracy: 0.9188 - val_loss: 0.2988 - val_accuracy: 0.8615
# Epoch 14/100
# 33/33 [==============================] - 1s 26ms/step - loss: 0.1952 - accuracy: 0.9149 - val_loss: 0.2867 - val_accuracy: 0.8705
# Epoch 15/100
# 33/33 [==============================] - 1s 24ms/step - loss: 0.1928 - accuracy: 0.9165 - val_loss: 0.2122 - val_accuracy: 0.9128
# Epoch 16/100
# 33/33 [==============================] - 1s 26ms/step - loss: 0.1791 - accuracy: 0.9269 - val_loss: 0.1963 - val_accuracy: 0.9205
# Epoch 17/100
# 33/33 [==============================] - 1s 26ms/step - loss: 0.1767 - accuracy: 0.9265 - val_loss: 0.2320 - val_accuracy: 0.9013
# Epoch 18/100
# 33/33 [==============================] - 1s 27ms/step - loss: 0.1773 - accuracy: 0.9275 - val_loss: 0.2102 - val_accuracy: 0.9090
# Epoch 19/100
# 33/33 [==============================] - 1s 25ms/step - loss: 0.1760 - accuracy: 0.9210 - val_loss: 0.2097 - val_accuracy: 0.9192
# Epoch 20/100
# 33/33 [==============================] - 1s 24ms/step - loss: 0.1648 - accuracy: 0.9333 - val_loss: 0.1859 - val_accuracy: 0.9244
# Epoch 21/100
# 33/33 [==============================] - 1s 25ms/step - loss: 0.1781 - accuracy: 0.9249 - val_loss: 0.3049 - val_accuracy: 0.8731
# Epoch 22/100
# 33/33 [==============================] - 1s 25ms/step - loss: 0.1660 - accuracy: 0.9278 - val_loss: 0.2813 - val_accuracy: 0.8795
# Epoch 23/100
# 33/33 [==============================] - 1s 25ms/step - loss: 0.1508 - accuracy: 0.9405 - val_loss: 0.2677 - val_accuracy: 0.8821
# Epoch 24/100
# 33/33 [==============================] - 1s 25ms/step - loss: 0.
sns.heatmap(mat, square=True, annot=True, fmt='d', cbar=False, cmap='Blues',
            xticklabels=labels, yticklabels=labels)
 
plt.xlabel('Predicted label')
plt.ylabel('Actual label')
# Out:
# Text(84.34, 0.5, 'Actual label')

# %%
print(classification_report(test_y, gru_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.89      0.90       390
#          1.0       0.89      0.92      0.91       390
#
#     accuracy                           0.90       780
#    macro avg       0.90      0.90      0.90       780
# weighted avg       0.90      0.90      0.90       780

# %%
def build_model_BILSTM():

    model=Sequential()
    
#     model.add(Conv1D(256, kernel_size=4, activation='relu', input_shape=(train_x.shape[1:])))
#     model.add(MaxPooling1D(2))
    
    model.add(Bidirectional(LSTM(256, input_shape=(train_x.shape[1:]), return_sequences=True)))
    model.add(Dropout(0.2))

    model.add(Bidirectional(LSTM(128, input_shape=(train_x.shape[1:]), return_sequences=True)))
    model.add(Dropout(0.2))

    model.add(Bidirectional(LSTM(64, input_shape=(train_x.shape[1:]), return_sequences=False)))
    model.add(Dropout(0.2))

    model.add(Dense(32, kernel_initializer="uniform", activation='tanh'))
    model.add(Dense(1, kernel_initializer="uniform", activation='sigmoid'))


    model.compile(loss='binary_crossentropy',optimizer="adam",metrics=['accuracy'])
    history=model.fit(train_x, train_y, batch_size=96, epochs=100, validation_data=(test_x,test_y))
    score=model.evaluate(test_x,test_y)
    bilstm_pred=model.predict(test_x) > 0.5
    
    print("Validation accuracy percentage",score[1])
    print("Validation loss percentage",score[0])
    print("Precision score", precision_score(test_y, bilstm_pred, average='macro'))
    print("Accuracy score", accuracy_score(test_y, bilstm_pred, normalize=True))
    
    return model, bilstm_pred

# %%
model_BILSTM, bilstm_pred = build_model_BILSTM()
# Out:
# Epoch 1/100
# 33/33 [==============================] - 12s 132ms/step - loss: 0.6879 - accuracy: 0.5392 - val_loss: 0.7028 - val_accuracy: 0.5192
# Epoch 2/100
# 33/33 [==============================] - 3s 77ms/step - loss: 0.6561 - accuracy: 0.6139 - val_loss: 0.6798 - val_accuracy: 0.5923
# Epoch 3/100
# 33/33 [==============================] - 3s 82ms/step - loss: 0.6384 - accuracy: 0.6340 - val_loss: 0.6612 - val_accuracy: 0.5962
# Epoch 4/100
# 33/33 [==============================] - 2s 74ms/step - loss: 0.6150 - accuracy: 0.6592 - val_loss: 0.6433 - val_accuracy: 0.6205
# Epoch 5/100
# 33/33 [==============================] - 2s 74ms/step - loss: 0.5844 - accuracy: 0.6981 - val_loss: 0.5881 - val_accuracy: 0.6731
# Epoch 6/100
# 33/33 [==============================] - 2s 72ms/step - loss: 0.5417 - accuracy: 0.7307 - val_loss: 0.4988 - val_accuracy: 0.7513
# Epoch 7/100
# 33/33 [==============================] - 2s 71ms/step - loss: 0.5127 - accuracy: 0.7456 - val_loss: 0.4933 - val_accuracy: 0.7769
# Epoch 8/100
# 33/33 [==============================] - 2s 71ms/step - loss: 0.4476 - accuracy: 0.7880 - val_loss: 0.4522 - val_accuracy: 0.7423
# Epoch 9/100
# 33/33 [==============================] - 2s 73ms/step - loss: 0.3637 - accuracy: 0.8282 - val_loss: 0.3021 - val_accuracy: 0.8641
# Epoch 10/100
# 33/33 [==============================] - 2s 72ms/step - loss: 0.3179 - accuracy: 0.8485 - val_loss: 0.2385 - val_accuracy: 0.8949
# Epoch 11/100
# 33/33 [==============================] - 2s 73ms/step - loss: 0
100
# 33/33 [==============================] - 2s 73ms/step - loss: 0.0976 - accuracy: 0.9625 - val_loss: 0.2666 - val_accuracy: 0.9115
# Epoch 82/100
# 33/33 [==============================] - 2s 74ms/step - loss: 0.1320 - accuracy: 0.9434 - val_loss: 0.2711 - val_accuracy: 0.9141
# Epoch 83/100
# 33/33 [==============================] - 2s 75ms/step - loss: 0.0730 - accuracy: 0.9676 - val_loss: 0.2723 - val_accuracy: 0.9256
# Epoch 84/100
# 33/33 [==============================] - 2s 73ms/step - loss: 0.0957 - accuracy: 0.9592 - val_loss: 0.3064 - val_accuracy: 0.8744
# Epoch 85/100
# 33/33 [==============================] - 2s 74ms/step - loss: 0.0781 - accuracy: 0.9676 - val_loss: 0.3442 - val_accuracy: 0.8962
# Epoch 86/100
# 33/33 [==============================] - 2s 73ms/step - loss: 0.0760 - accuracy: 0.9670 - val_loss: 0.3122 - val_accuracy: 0.9026
# Epoch 87/100
# 33/33 [==============================] - 2s 75ms/step - loss: 0.0763 - accuracy: 0.9680 - val_loss: 0.3613 - val_accuracy: 0.9013
# Epoch 88/100
# 33/33 [==============================] - 2s 73ms/step - loss: 0.0837 - accuracy: 0.9654 - val_loss: 0.2573 - val_accuracy: 0.9231
# Epoch 89/100
# 33/33 [==============================] - 2s 73ms/step - loss: 0.0903 - accuracy: 0.9612 - val_loss: 0.3475 - val_accuracy: 0.9051
# Epoch 90/100
# 33/33 [==============================] - 2s 73ms/step - loss: 0.0638 - accuracy: 0.9751 - val_loss: 0.3584 - val_accuracy: 0.9128
# Epoch 91/100
# 33/33 [==============================] - 2s 75ms/step - loss: 0.0903 - accuracy: 0.9612 - val_loss: 0.3712 - val_accuracy: 0.8923
# Epoch 92/100
# 33/33 [==============================] - 2s 73ms/step - loss: 0.0655 - accuracy: 0.9725 - val_loss: 0.4881 - val_accuracy: 0.8679
# Epoch 93/100
# 33/33 [==============================] - 2s 75ms/step - loss: 0.0737 - accuracy: 0.9654 - val_loss: 0.2945 - val_accuracy: 0.9167
# Epoch 94/100
# 33/33 [==============================] - 2s 73ms/step - loss: 0.0658 - accuracy: 0.9715 - val_loss: 0.4645 - val_accuracy: 0.8782
# Epoch 95/100
# 33/33 [==============================] - 2s 75ms/step - loss: 0.0909 - accuracy: 0.9621 - val_loss: 0.3829 - val_accuracy: 0.8769
# Epoch 96/100
# 33/33 [==============================] - 3s 78ms/step - loss: 0.0926 - accuracy: 0.9625 - val_loss: 0.3068 - val_accuracy: 0.9154
# Epoch 97/100
# 33/33 [==============================] - 2s 73ms/step - loss: 0.0682 - accuracy: 0.9709 - val_loss: 0.4076 - val_accuracy: 0.8885
# Epoch 98/100
# 33/33 [==============================] - 2s 73ms/step - loss: 0.0687 - accuracy: 0.9722 - val_loss: 0.5303 - val_accuracy: 0.8564
# Epoch 99/100
# 33/33 [==============================] - 2s 74ms/step - loss: 0.0713 - accuracy: 0.9706 - val_loss: 0.4295 - val_accuracy: 0.8936
# Epoch 100/100
# 33/33 [==============================] - 2s 74ms/step - loss: 0.0638 - accuracy: 0.9728 - val_loss: 0.3764 - val_accuracy: 0.8962
# 25/25 [==============================] - 0s 15ms/step - loss: 0.3764 - accuracy: 0.8962
# Validation accuracy percentage 0.8961538672447205
# Validation loss percentage 0.37643715739250183
# Precision score 0.9019921142697027
# Accuracy score 0.8961538461538462

# %%
mat = confusion_matrix(test_y, bilstm_pred)
labels = ['Legitimate', 'Fraudulent']
 
sns.heatmap(mat, square=True, annot=True, fmt='d', cbar=False, cmap='Blues',
            xticklabels=labels, yticklabels=labels)
 
plt.xlabel('Predicted label')
plt.ylabel('Actual label')
# Out:
# Text(84.34, 0.5, 'Actual label')

# %%
print(classification_report(test_y, bilstm_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.84      0.89       390
#          1.0       0.85      0.96      0.90       390
#
#     accuracy                           0.90       780
#    macro avg       0.90      0.90      0.90       780
# weighted avg       0.90      0.90      0.90       780
